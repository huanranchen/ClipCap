# %%
# !pip install gdown
# !pip3 install torch==1.11.0 torchvision==0.12.0 torchaudio --extra-index-url https://download.pytorch.org/whl/cu113
# !pip install transformers

# %%
# !gdown 1xJM6xgw71fxOUVWmqKyzs8C7hi7C8Nok
# !unzip -o ClipInMyIdea

# %%
import torch
import torch.nn as nn
from tqdm import tqdm
from models.encoders import ImgEncoder, TextEncoder
from data.data import get_train_loader
import math
from data.Tokens import MyToken
from data.dataUtils import read_into_dic
from ContrastiveTraining import *


tokenizer = MyToken()
tokenizer.load_dic()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
img_encoder = ImgEncoder().to(device)
text_encoder = TextEncoder(device=device, tokenizer=tokenizer).to(device)
train_loader, _ = get_train_loader(image_path = '../input/flickr8k/Flickr_Data/Flickr_Data/Images/', 
                                   lemma_path = '../input/flickr8k/Flickr_Data/Flickr_Data/Flickr_TextData/Flickr8k.lemma.token.txt',
                                   batch_size=32,
                                  )
contrastive_training(img_encoder, text_encoder, train_loader,total_epoch = 100,t = 100)
