# %%
# !pip install gdown
# !pip3 install torch==1.11.0 torchvision==0.12.0 torchaudio --extra-index-url https://download.pytorch.org/whl/cu113
# !pip install transformers

# %%
# !gdown 1xJM6xgw71fxOUVWmqKyzs8C7hi7C8Nok
# !unzip -o ClipInMyIdea

# %%
import shutil
shutil.copy('../input/clippretraining/image_encoder.pth','./encoder.ckpt')

# %%
from ClipCapTraining import train
train(lr = 1e-3,
      image_path = '../input/flickr8k/Flickr_Data/Flickr_Data/Images/',lemma_path = '../input/flickr8k/Flickr_Data/Flickr_Data/Flickr_TextData/Flickr8k.lemma.token.txt',total_epoch = 10)

# %%
from ClipCapTraining import train
train(lr = 1e-4,
      image_path = '../input/flickr8k/Flickr_Data/Flickr_Data/Images/',lemma_path = '../input/flickr8k/Flickr_Data/Flickr_Data/Flickr_TextData/Flickr8k.lemma.token.txt',total_epoch = 10)

# %%
print('_____________________________________________________________________________')
from ClipCapTraining import train
train(lr = 1e-5,
      image_path = '../input/flickr8k/Flickr_Data/Flickr_Data/Images/',lemma_path = '../input/flickr8k/Flickr_Data/Flickr_Data/Flickr_TextData/Flickr8k.lemma.token.txt',total_epoch = 10)
