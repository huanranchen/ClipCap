# %%
# !pip install gdown
# !pip3 install torch==1.11.0 torchvision==0.12.0 torchaudio --extra-index-url https://download.pytorch.org/whl/cu113
# !pip install transformers

# %%
# !gdown 1xJM6xgw71fxOUVWmqKyzs8C7hi7C8Nok
# !unzip -o ClipInMyIdea

# %%
# !gdown 1_V9LOcEkjzFCn0gODLEAz-xAjjC2FJk8
# !unzip -o outs

# %%
from ClipCapTraining import train
train(image_path = '../input/flickr8k/Flickr_Data/Flickr_Data/Images/',lemma_path = '../input/flickr8k/Flickr_Data/Flickr_Data/Flickr_TextData/Flickr8k.lemma.token.txt',)
